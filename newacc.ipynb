# %%
import pandas as pd 
import cv2

import os

# %%
base_root = os.path.abspath('D:\handpose')
#print(base_root)
#filename_list = []
vidoefilepath_list = []
for filename in os.listdir(base_root):
    #filename_list.append(filename)
    if filename == 'notuse':
        continue
    path1 = base_root + "\\"+ filename
    for vidoefilename in os.listdir(path1):
        vidoefilepath_list.append(path1  + "\\"+  vidoefilename)

# %%
vidoefilepath_list
# Out:
# ['D:\\handpose\\clench\\2021-06-29_04-24-52.mp4',
#  'D:\\handpose\\clench\\2021-06-29_04-24-57.mp4',
#  'D:\\handpose\\clench\\2021-06-29_04-25-16.mp4',
#  'D:\\handpose\\clench\\2021-06-29_04-26-01.mp4',
#  'D:\\handpose\\clench\\2021-06-30_01-27-53.mp4',
#  'D:\\handpose\\clench\\2021-06-30_01-27-59.mp4',
#  'D:\\handpose\\clench\\2021-06-30_01-28-03.mp4',
#  'D:\\handpose\\clench\\2021-06-30_05-18-52.mp4',
#  'D:\\handpose\\clench\\2021-06-30_05-18-56.mp4',
#  'D:\\handpose\\clench\\2021-06-30_05-18-59.mp4',
#  'D:\\handpose\\clench\\2021-06-30_05-19-04.mp4',
#  'D:\\handpose\\clench\\2021-06-30_05-19-06.mp4',
#  'D:\\handpose\\clench\\2021-06-30_05-19-19.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-20-01.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-20-05.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-20-08.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-20-11.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-20-14.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-20-16.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-20-18.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-20-21.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-20-23.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-24-57.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-25-00.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-25-02.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-25-04.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-25-06.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-25-07.mp4',
#  'D:\\handpose\\click\\2021-06-30_05-25-09.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-29.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-32.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-35.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-38.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-40.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-43.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-45.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-47.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-49.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-51.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-53.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-54.mp4',
#  'D:\\handpose\\close\\2021-06-30_05-43-56.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-27-33.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-27-38.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-27-41.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-27-47.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-27-49.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-27-53.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-27-56.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-28-12.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-28-55.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-28-58.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-29-04.mp4',
#  'D:\\handpose\\fetch\\2021-06-29_04-29-09.mp4',
#  'D:\\handpose\\good\\2021-06-30_05-32-59.mp4',
#  'D:\\handpose\\good\\2021-06-30_05-33-01.mp4',
#  'D:\\handpose\\good\\2021-06-30_05-33-04.mp4',
#  'D:\\handpose\\good\\2021-06-30_05-33-07.mp4',
#  'D:\\handpose\\good\\2021-06-30_05-33-10.mp4',
#  'D:\\handpose\\good\\2021-06-30_05-33-14.mp4',
#  'D:\\handpose\\good\\2021-06-30_05-33-17.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-21.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-23.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-26.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-28.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-30.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-32.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-35.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-37.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-38.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-40.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-43.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-45.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-48.mp4',
#  'D:\\handpose\\goup\\2021-06-30_05-35-50.mp4',
#  'D:\\handpose\\moving\\2021-06-29_04-37-36.mp4',
#  'D:\\handpose\\moving\\2021-06-29_04-38-10.mp4',
#  'D:\\handpose\\moving\\2021-06-29_04-38-29.mp4',
#  'D:\\handpose\\moving\\2021-06-30_05-23-46.mp4',
#  'D:\\handpose\\noise\\2021-06-30_05-19-36.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-16.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-25.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-32.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-35.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-38.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-41.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-45.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-48.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-52.mp4',
#  'D:\\handpose\\ok\\2021-06-30_05-37-55.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-13-55.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-14-04.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-14-07.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-14-10.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-14-13.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-14-20.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-14-25.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-14-30.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-14-36.mp4',
#  'D:\\handpose\\punch\\2021-06-30_05-14-40.mp4',
#  'D:\\handpose\\wave\\2021-06-30_05-29-45.mp4',
#  'D:\\handpose\\wave\\2021-06-30_05-29-47.mp4',
#  'D:\\handpose\\wave\\2021-06-30_05-29-50.mp4',
#  'D:\\handpose\\wave\\2021-06-30_05-29-52.mp4',
#  'D:\\handpose\\wave\\2021-06-30_05-29-55.mp4',
#  'D:\\handpose\\wave\\2021-06-30_05-29-57.mp4',
#  'D:\\handpose\\wave\\2021-06-30_05-30-00.mp4',
#  'D:\\handpose\\wave\\2021-06-30_05-30-03.mp4',
#  'D:\\handpose\\wave\\2021-06-30_05-30-06.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-27.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-30.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-33.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-34.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-37.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-40.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-43.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-45.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-48.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-51.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-54.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-57.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-21-59.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-22-02.mp4',
#  'D:\\handpose\\zoom\\2021-06-30_05-22-05.mp4']

# %%
import mediapipe as mp

mpDraw = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %%
for video in vidoefilepath_list:
    cap = cv2.VideoCapture(video)
    with mp_hands.Hands(max_num_hands=1,
                        min_detection_confidence=0.7,
                        min_tracking_confidence=0.7) as hands:
        while cap.isOpened():
            success, image = cap.read()
            if not success:
                print("Ignoring empty camera frame.")
                # If loading a video, use 'break' instead of 'continue'.
                break

            # Flip the image horizontally for a later selfie-view display, and convert
            # the BGR image to RGB.
            image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
            # To improve performance, optionally mark the image as not writeable to
            # pass by reference.
            image.flags.writeable = False
            results = hands.process(image)

            # Draw the hand annotations on the image.
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
            if results.multi_hand_landmarks:
                keypoints = []
                for handLms in results.multi_hand_landmarks:
                    for _, data_point in enumerate(handLms.landmark):
                        keypoints += [data_point.x, data_point.y, data_point.z]
                        mpDraw.draw_landmarks(image, handLms,
                                            mp_hands.HAND_CONNECTIONS)
                        dataframe = pd.DataFrame(keypoints)
                    mpDraw.draw_landmarks(image, handLms,
                                        mp_hands.HAND_CONNECTIONS)
            else:
                keypoints = [0] * 63
            dataframe = pd.DataFrame(keypoints)
            (dataframe.T).to_csv('./data/' + video.split('\\')[2] + '.csv',
                                mode='a',
                                header=False,
                                index=False)
            cv2.imshow('Frame', image)
            if cv2.waitKey(5) & 0xFF == 27:
                break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
